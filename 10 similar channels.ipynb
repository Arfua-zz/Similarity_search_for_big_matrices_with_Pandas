# %% [markdown]
# ## Finding 10 similar Youtube channels

# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import os
import matplotlib.pylab as plt
from numpy.random import RandomState
import copy
import csv

from sklearn.neighbors import NearestNeighbors
#from sklearn.neighbors import LSHForest

# %%
data_train_act = pd.read_csv(r'C:\Users\user\Anaconda3\activities.csv.gz', 
                        sep = ',',
                       )
data_channels = pd.read_csv(r'C:\Users\user\Anaconda3\channels.csv.gz', 
                        sep = ',',
                       )

# %% [markdown]
# ### 1st model - subscribed on > 10 channels (similarity by audience)

# %%
# number of users and channels
n_users = data_train_act.author_id.unique().shape[0]
n_items = data_train_act.channel_id.unique().shape[0]

# %%
# type of action
type_s = 'subscribed'
type_c = 'commented'

# %%
def grouped_by_user(data, act_type):    
    return data[data.activity == act_type].groupby('author_id').agg({'created_at': pd.Series.nunique,
                        'channel_id': pd.Series.tolist})

# %%
def add_channels_as_features(data_grouped_by_user, max_num_actions):
    data_grouped_by_user = data_grouped_by_user[data_grouped_by_user.created_at > max_num_actions]
    for channel in channels:
        data_grouped_by_user[channel] = [channel in a for a in data_grouped_by_user.channel_id]    
    print(data_grouped_by_user.shape)
    return data_grouped_by_user

# %%
def create_channel_by_user_matrix(data_with_channels):
    return data_with_channels[channels].transpose()

# %%
def train_nearest_neigbours_model(data_to_train, params):
    nn = NearestNeighbors(**params)
    nn = nn.fit(data_to_train)
    result_neighbors = nn.kneighbors(data_to_train, return_distance = True)
    return result_neighbors

# %%
def add_k_closest(data_channels, train_channels, model_results, k, prefix):
    for nghbr_num in range(1, k):
        name = prefix+str(nghbr_num)
        name_id = name + '_id'
        names = list()
        name_ids = list()
        for channel_id in list(data_channels.YT_id):
            i = train_channels.index(channel_id)
            nn_ix = model_results[1][i][nghbr_num]
            names.append(data_channels.ix[nn_ix].YT_Title)
            name_ids.append(data_channels.ix[nn_ix].YT_id)
        data_channels[name] = names
        data_channels[name_id] = name_ids
    return data_channels

# %%
### Find neigbors with subscribed dataset:

# %%
channels = list(data_channels.YT_id.values)
print(len(channels))
# Out:
# 1000

# %%
data_act_grouped = grouped_by_user(data_train_act, type_s)
print(data_act_grouped.shape)
print('index:', data_act_grouped.index.names, ' columns:',data_act_grouped.columns.values)
# Out:
# (8864137, 2)
# index: ['author_id']  columns: ['created_at' 'channel_id']

# %%
sum(data_act_grouped.created_at > 10)
# Out:
# 20858

# %%
data_act_grouped = add_channels_as_features(data_act_grouped, 10)
#print(data_act_grouped.shape)
data_to_train = create_channel_by_user_matrix(data_act_grouped)
print(data_to_train.shape)
# Out:
# (20858, 1002)
# (1000, 20858)

# %%
# TRAIN MODEL WITH DEFINED SET OF PARAMETERS:
params = {'n_neighbors': 10, 'metric': 'jaccard', 'algorithm': 'brute'}
results_subscribed_jaccard = train_nearest_neigbours_model(data_to_train, params)

# %%
def show_neighbors(user_index, model_results):
    nn_ix = model_results[1][user_index]
    print(data_channels.ix[nn_ix][['YT_Title', 'country', 'YT_category', 'YT_Total_Subscribers']])

# %%
show_neighbors(0, results_subscribed_jaccard)
show_neighbors(2, results_subscribed_jaccard)
show_neighbors(273, results_subscribed_jaccard)
# Out:
#              YT_Title country YT_category  YT_Total_Subscribers
# 0    JustinBieberVEVO      US       Music              20974056
# 35    TaylorSwiftVEVO      US       Music              18952084
# 39   OneDirectionVEVO      GB       Music              19931142
# 14        RihannaVEVO      US       Music              20489720
# 60   ArianaGrandeVevo      US       Music              10961767
# 74      KatyPerryVEVO      US       Music              18405805
# 127   SelenaGomezVEVO      US       Music               9119991
# 38          AdeleVEVO      GB       Music              11500000
# 58   FifthHarmonyVEVO      US       Music               4505141
# 110         DrakeVEVO      US       Music               5319146
#                  YT_Title country       YT_category  YT_Total_Subscribers
# 2                     WWE      US            Sports              10964777
# 49    Movieclips Trailers      US  Film & Animation               9069807
# 748          PrankvsPrank      US            Comedy               9892516
# 422  JoBlo Movie Trailers      CA     Entertainment               1240053
# 151       The Young Turks      US   News & Politics               2840008
# 175             Team Coco      US     Entertainment               3959907
# 265          CollegeHumor      US            Comedy              10759425
# 322                   NBA      US            Sports               6897272
# 437              ABC News      US   News & Politics               1716657
# 170          Dude Perfect      US            Sports               9472991
#                                               YT_Title country  \
# 273                                       Mega Kids Tv      US
# 104  Kids Channel - Baby Nursery Rhymes & Cars Truc...      US
# 105                                           FOR KIDS     NaN
# 173                                The Little Bus Tayo      KR
# 319                           onegamesplus Disney cars      US
# 416                                         Morphle TV      US
# 94                                          DisneyCARS      GB
# 500                                  Crazy Baby Rhymes     NaN
# 234                                           TuTiTuTV      IL
# 5                                      LittleBabyBum ®      GB
#
#           YT_category  YT_Total_Subscribers
# 273     Entertainment                610833
# 104         Education               1175762
# 105               NaN                437578
# 173  Film & Animation               1033454
# 319    People & Blogs                360522
# 416         Education                396655
# 94   Film & Animation                 24720
# 500               NaN                277394
# 234  Film & Animation               2231010
# 5           Education               6122038

# %%
# add 9 closest friends (1st is same channel - the closest)
data_channels = add_k_closest(data_channels, list(data_to_train.index.values), results_subscribed_jaccard, 10, 'model1_NN_')

# %%
# CHECK JACCARD DISTANCE:

def jaccard_distance(data_to_train, index1, index2):
    intersection = sum(np.array(data_to_train.ix[index1]) & np.array(data_to_train.ix[index2]))
    union = sum(np.array(data_to_train.ix[index1]) | np.array(data_to_train.ix[index2]))
    return 1 - intersection / union

print(results_subscribed_jaccard[0][0][1])
print(results_subscribed_jaccard[1][0][1])
print('check:',jaccard_distance(data_to_train, 0, 35))
print('')
print(results_subscribed_jaccard[0][0][9])
print(results_subscribed_jaccard[1][0][9])
print('check:',jaccard_distance(data_to_train, 0, 110))
# Out:
# 0.809921811809
# 35
# check: 0.809921811809
#
# 0.877620396601
# 110
# check: 0.877620396601

# %%
# save results of the 1st model:
import csv
data_channels.to_csv('A:\PROGRAMMING\Tubular_results\First_model_results.csv', 
                                             sep = ',' ,index= False,encoding = 'utf-8')

# %% [markdown]
# ### 2nd model (similarity by general information)

# %%
## Create numerical categories:
category = list(set(data_channels['country']))
data_channels['country_ix'] = [category.index(i) for i in data_channels['country']]
category = list(set(data_channels['YT_category']))
data_channels['YT_category_ix'] = [category.index(i) for i in data_channels['YT_category']]

# %%
## Create set of all possible topics from channels dataset:
topics = set()
for topic_set in data_channels.topics:
    if pd.isnull(topic_set):
        pass
    else:        
        topics |= set(topic_set.upper().split(','))
print('First 10 topics', list(topics)[:10])
print('Last 10 topics', list(topics)[-10:])
print(len(list(topics)))
# Out:
# First 10 topics ['DREAMWORKS ANIMATION', 'SPANISH LANGUAGE', 'ATV', 'CARTOON NETWORK', 'WEST COAST HIP HOP', 'FIRST LADY OF THE UNITED STATES', 'BOSTON RED SOX', 'GOOGLE PLAY', 'REAL-LIFE SUPERHERO', 'GOOGLE']
# Last 10 topics ['POLLY POCKET', 'APPLE DAILY', 'MINECRAFT', 'JOSEPH GARRETT', 'THE VERGE', 'BINOMIO DE ORO DE AMÉRICA', 'WA', 'PSY', 'GOIÂNIA', 'THE VOICE UK']
# 1699

# %%
def check_word_in_topics(data, word):
    check = list()    
    for i in range(len(data)):
        topics_i = data.topics[i]
        if pd.isnull(topics_i):
            check.append(False)
        else:
            check.append(word in topics_i.upper().split(','))
    return check

# %%
### ADD TOPICS AS FEATURES:
for word in list(topics):
    data_channels[word] = check_word_in_topics(data_channels, word)

# %%
print('Number of topics added as features:', data_channels[list(topics)].shape[1])
# Out:
# Number of topics added as features: 1699

# %%
features_top = list(topics)
data_channels['scaled_subscriptions'] = data_channels.YT_Total_Subscribers / data_channels.YT_Total_Subscribers.max()
features_top.extend(['scaled_subscriptions', 'country_ix'])

params = {'n_neighbors': 10, 'metric': 'minkowski', 'algorithm': 'brute'}
result_topics = train_nearest_neigbours_model(data_channels[features_top], params)

# %%
show_neighbors(0, result_topics)
show_neighbors(2, result_topics)
show_neighbors(1, result_topics)
# Out:
#               YT_Title country YT_category  YT_Total_Subscribers
# 0     JustinBieberVEVO      US       Music              20974056
# 285               ELLO      US       Music               2176108
# 17            emimusic      US       Music               5360039
# 110          DrakeVEVO      US       Music               5319146
# 540  BlackEyedPeasVEVO      US       Music               2628326
# 807           NeYoVEVO      US       Music               1661516
# 333   ChainsmokersVEVO      US       Music                687240
# 274   NickiMinajAtVEVO      US       Music              10508077
# 223         Bruno Mars      US       Music              10327921
# 137        beyonceVEVO      US       Music               9297164
#                                  YT_Title country            YT_category  \
# 2                                     WWE      US                 Sports
# 577  UFC - Ultimate Fighting Championship      US                 Sports
# 658                  SuperHero Reality TV      US       Film & Animation
# 980                               NowThis      US        News & Politics
# 991                                   Mic      US        News & Politics
# 803                            JukinVideo      US          Entertainment
# 297                           TomoNews US      US        News & Politics
# 352                        Inside Edition      US       Film & Animation
# 926                         GOOD Magazine      US  Nonprofits & Activism
# 126                              FailArmy      US          Entertainment
#
#      YT_Total_Subscribers
# 2                10964777
# 577               2866188
# 658                283396
# 980                     0
# 991                     0
# 803               1249341
# 297                971532
# 352                203735
# 926                 75434
# 126              10338295
#                                   YT_Title country      YT_category  \
# 1                          Ryan ToysReview      US    Entertainment
# 584                             Kid Studio      US    Entertainment
# 42   Blu Toys Surprise Brinquedos & Juegos      US    Entertainment
# 206                            Hulyan Maya      US    Entertainment
# 861                               CNNMoney      US  News & Politics
# 3                          Family Fun Pack      US   People & Blogs
# 395                            EvanTubeRAW      US   People & Blogs
# 336                             babyteeth4      US    Entertainment
# 139                                  Vat19      US    Entertainment
# 803                             JukinVideo      US    Entertainment
#
#      YT_Total_Subscribers
# 1                 2439921
# 584                211770
# 42                3752016
# 206                754290
# 861                123336
# 3                 2266855
# 395               1570187
# 336                891158
# 139               2435875
# 803               1249341

# %%
# add 9 closest friends (1st is same channel - the closest)
data_channels = add_k_closest(data_channels, list(data_channels.YT_id), result_topics, 10, 'model2_NN_')

# %%
# save results of the 1st AND 2nd models:
import csv
data_channels.to_csv('A:\PROGRAMMING\Tubular_results\First_AND_Second_model_results.csv', 
                                             sep = ',' ,index= False,encoding = 'utf-8')

# %%
data_channels[['model1_NN_1', 'model1_NN_2', 'model2_NN_1', 'model2_NN_2']][:3]
# Out:
#            model1_NN_1       model1_NN_2  \
# 0      TaylorSwiftVEVO  OneDirectionVEVO
# 1      Family Fun Pack    Baby Big Mouth
# 2  Movieclips Trailers      PrankvsPrank
#
#                             model2_NN_1                            model2_NN_2
# 0                                  ELLO                               emimusic
# 1                            Kid Studio  Blu Toys Surprise Brinquedos & Juegos
# 2  UFC - Ultimate Fighting Championship                   SuperHero Reality TV

# %% [markdown]
# ### 3d model - commented on > x channels (similarity by audience)

# %%
data_act_grouped = grouped_by_user(data_train_act, type_c)
print(data_act_grouped.shape)
print('index:', data_act_grouped.index.names, ' columns:',data_act_grouped.columns.values)
# Out:
# (9423299, 2)
# index: ['author_id']  columns: ['created_at' 'channel_id']

# %%
sum(data_act_grouped.created_at>30)
# Out:
# 21625

# %%
data_act_grouped = add_channels_as_features(data_act_grouped, 30)
#print(data_act_grouped.shape)
data_to_train = create_channel_by_user_matrix(data_act_grouped)
print(data_to_train.shape)

# TRAIN MODEL WITH DEFINED SET OF PARAMETERS:
params = {'n_neighbors': 10, 'metric': 'jaccard', 'algorithm': 'brute'}
results_commented_jaccard = train_nearest_neigbours_model(data_to_train, params)
# Out:
# (21625, 1002)
# (1000, 21625)
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
show_neighbors(0, results_commented_jaccard)
show_neighbors(2, results_commented_jaccard)
show_neighbors(200, results_commented_jaccard)
# Out:
#               YT_Title country YT_category  YT_Total_Subscribers
# 0     JustinBieberVEVO      US       Music              20974056
# 14         RihannaVEVO      US       Music              20489720
# 35     TaylorSwiftVEVO      US       Music              18952084
# 58    FifthHarmonyVEVO      US       Music               4505141
# 39    OneDirectionVEVO      GB       Music              19931142
# 60    ArianaGrandeVevo      US       Music              10961767
# 38           AdeleVEVO      GB       Music              11500000
# 128  MeghanTrainorVEVO      US       Music               5356018
# 66         Wiz Khalifa      US       Music               7786975
# 338        officialpsy      KR       Music               8980066
#                                    YT_Title country    YT_category  \
# 2                                       WWE      US         Sports
# 321                       ComedyShortsGamer      GB  Entertainment
# 202                                     IGN      US         Gaming
# 27                            WatchMojo.com      CA  Entertainment
# 577    UFC - Ultimate Fighting Championship      US         Sports
# 276                    Marvel Entertainment      US  Entertainment
# 351                                     KSI      GB         Gaming
# 51   The Tonight Show Starring Jimmy Fallon      US         Comedy
# 221                                     W2S      GB         Gaming
# 392             Sony Pictures Entertainment      US  Entertainment
#
#      YT_Total_Subscribers
# 2                10964777
# 321               6225208
# 202               7099270
# 27               11602147
# 577               2866188
# 276               3002349
# 351              12525628
# 51               10709249
# 221               6423298
# 392                990209
#              YT_Title country YT_category  YT_Total_Subscribers
# 200      Charlie Puth      US       Music               2427953
# 107   ShawnMendesVEVO      US       Music               3557602
# 127   SelenaGomezVEVO      US       Music               9119991
# 344       JessieJVEVO      GB       Music               4757458
# 157        Ed Sheeran      GB       Music               8588356
# 66        Wiz Khalifa      US       Music               7786975
# 58   FifthHarmonyVEVO      US       Music               4505141
# 35    TaylorSwiftVEVO      US       Music              18952084
# 74      KatyPerryVEVO      US       Music              18405805
# 184    DemiLovatoVEVO      US       Music               8966493

# %%
# add 9 closest friends (1st is same channel - the closest)
data_channels = add_k_closest(data_channels, list(data_to_train.index.values), results_commented_jaccard, 10, 'model3_NN_')

# %%
# save results of the 1st AND 2nd AND 3d models:
import csv
data_channels.to_csv('A:\PROGRAMMING\Tubular_results\First_AND_Second_AND_third_model_results.csv', 
                                             sep = ',' ,index= False,encoding = 'utf-8')

# %%
data_channels[['model1_NN_1', 'model1_NN_2', 'model2_NN_1', 'model2_NN_2', 'model3_NN_1', 'model3_NN_2']][:3]
# Out:
#            model1_NN_1       model1_NN_2  \
# 0      TaylorSwiftVEVO  OneDirectionVEVO
# 1      Family Fun Pack    Baby Big Mouth
# 2  Movieclips Trailers      PrankvsPrank
#
#                             model2_NN_1  \
# 0                                  ELLO
# 1                            Kid Studio
# 2  UFC - Ultimate Fighting Championship
#
#                              model2_NN_2        model3_NN_1      model3_NN_2
# 0                               emimusic        RihannaVEVO  TaylorSwiftVEVO
# 1  Blu Toys Surprise Brinquedos & Juegos     Baby Big Mouth      ToyTrains4u
# 2                   SuperHero Reality TV  ComedyShortsGamer              IGN

# %% [markdown]
# ### Building final model

# %%
def extend_k1_with_unique_k2(list1, k1, list2, k2):
    list3 = list1[:k1]
    uniq_list2 = [f for f in list2 if f not in list3]
    list3.extend(uniq_list2[:k2])
    return list3
print(extend_with_unique_k2([1,2,6,4,2,6,6,7,4,4], 5, [2,6,7,9,8,0], 3))
# Out:
# [1, 2, 6, 4, 2, 7, 9, 8]

# %%
nn1_list = list()
nn2_list = list()
nn3_list = list()
for i in range(1,10):
    nn1_list.append('model1_NN_'+str(i))
    nn2_list.append('model2_NN_'+str(i))
    nn3_list.append('model3_NN_'+str(i))
print(nn1_list)
# Out:
# ['model1_NN_1', 'model1_NN_2', 'model1_NN_3', 'model1_NN_4', 'model1_NN_5', 'model1_NN_6', 'model1_NN_7', 'model1_NN_8', 'model1_NN_9']

# %%
a1 = list(data_channels[nn1_list].ix[0].values)
print(a1)
a2 = list(data_channels[nn2_list].ix[0].values)
print(a2)
a3 = list(data_channels[nn3_list].ix[0].values)
print(a3)
a4 = extend_k1_with_unique_k2(a1,6,a2,2)
print(extend_k1_with_unique_k2(a4,8,a3,2))
# Out:
# ['TaylorSwiftVEVO', 'OneDirectionVEVO', 'RihannaVEVO', 'ArianaGrandeVevo', 'KatyPerryVEVO', 'SelenaGomezVEVO', 'AdeleVEVO', 'FifthHarmonyVEVO', 'DrakeVEVO']
# ['ELLO', 'emimusic', 'DrakeVEVO', 'BlackEyedPeasVEVO', 'NeYoVEVO', 'ChainsmokersVEVO', 'NickiMinajAtVEVO', 'Bruno Mars', 'beyonceVEVO']
# ['RihannaVEVO', 'TaylorSwiftVEVO', 'FifthHarmonyVEVO', 'OneDirectionVEVO', 'ArianaGrandeVevo', 'AdeleVEVO', 'MeghanTrainorVEVO', 'Wiz Khalifa', 'officialpsy']
# ['TaylorSwiftVEVO', 'OneDirectionVEVO', 'RihannaVEVO', 'ArianaGrandeVevo', 'KatyPerryVEVO', 'SelenaGomezVEVO', 'ELLO', 'emimusic', 'FifthHarmonyVEVO', 'AdeleVEVO']

# %%
def add_final(data, names1, k1, names2, k2, names3, k3, prefix, postfix):
    all_final_unique_neighbors = list()
    for i in range(len(data)):
        a1 = list(data[names1].ix[i].values)
        a2 = list(data[names2].ix[i].values)
        a3 = list(data[names3].ix[i].values)
        a4 = extend_k1_with_unique_k2(a1, k1, a2, k2)
        a4 = extend_k1_with_unique_k2(a4, k1+k2, a3, k3)
        all_final_unique_neighbors.append(a4)
    for i in range(10):
        name = prefix + str(i+1)+postfix
        data[name] = [neighbor[i] for neighbor in all_final_unique_neighbors]
    return data

# %%
data_channels = add_final(data_channels, nn1_list, 6, nn2_list, 2, nn3_list, 2, 'Final_Neighbor_', '')

# %%
data_channels[[ 'YT_Title','Final_Neighbor_1', 'Final_Neighbor_2', 'Final_Neighbor_3', 
               'Final_Neighbor_6', 'Final_Neighbor_8']]
# Out:
#                                     YT_Title  \
# 0                           JustinBieberVEVO
# 1                            Ryan ToysReview
# 2                                        WWE
# 3                            Family Fun Pack
# 4                                   T-Series
# 5                            LittleBabyBum ®
# 6                                 netd müzik
# 7                             Маша и Медведь
# 8                                Toy Monster
# 9                                 Get Movies
# 10                 Disney Cars Toy Club DCTC
# 11                              TheEllenShow
# 12                             Drake - Topic
# 13              TheDiamondMinecart // DanTDM
# 14                               RihannaVEVO
# 15                            Baby Big Mouth
# 16                  ChuChu TV Nursery Rhymes
# 17                                  emimusic
# 18                                 Miss Katy
# 19                          FunToyzCollector
# 20                             BuzzFeedVideo
# 21                         El Reino Infantil
# 22                                 PewDiePie
# 23                       GMM GRAMMY OFFICIAL
# 24                               PopularMMOs
# 25                                ToyMonster
# 26                     ABS-CBN Entertainment
# 27                             WatchMojo.com
# 28                           SevenSuperGirls
# 29                                Mister Max
# ..                                       ...
# 970                                 slamball
# 971                          Brittany Furlan
# 972                                 Upworthy
# 973                       The Wall of Comedy
# 974                                Jaan Arya
# 975                           Chef Kiwilimón
# 976                             CurtisLepore
# 977                               Lil Crazed
# 978                      Sky Sports Football
# 979                                Bizim Yol
# 980                                  NowThis
# 981                              MONTREALITY
# 982                                 Facebook
# 983                             Rudy Mancuso
# 984                             Food Network
# 985                         Spoon University
# 986                                     HGTV
# 987                        PZS ENTERTAINMENT
# 988                              HipHopVines
# 989                       Japonês da Federal
# 990                              bandeandofm
# 991                                      Mic
# 992                                   helloU
# 993                                    3ga2b
# 994  The Black Jaguar White Tiger Foundation
# 995                         PlayGround Video
# 996                       شبكة قدس الاخبارية
# 997                              Milly Wessy
# 998                     Collective Evolution
# 999                                Global TV
#
#                                  Final_Neighbor_1  \
# 0                                 TaylorSwiftVEVO
# 1                                 Family Fun Pack
# 2                             Movieclips Trailers
# 3                                 Ryan ToysReview
# 4                                        Eros Now
# 5                        ChuChu TV Nursery Rhymes
# 6                                DokuzSekiz Müzik
# 7                                      Get Movies
# 8                                       HeroesIRL
# 9                                  Маша и Медведь
# 10                                   CookieSwirlC
# 11         The Tonight Show Starring Jimmy Fallon
# 12                                 Future - Topic
# 13                                    PopularMMOs
# 14                               JustinBieberVEVO
# 15                                LittleBabyBum ®
# 16                                LittleBabyBum ®
# 17                              BritneySpearsVEVO
# 18                                     Mister Max
# 19                                 Baby Big Mouth
# 20                                 BuzzFeedYellow
# 21                               GallinaPintadita
# 22                                     Markiplier
# 23                                       ช่อง one
# 24                   TheDiamondMinecart // DanTDM
# 25              Toys and Funny Kids Surprise Eggs
# 26                    GMA News and Public Affairs
# 27                                     TheRichest
# 28                             SevenPerfectAngels
# 29                                      Miss Katy
# ..                                            ...
# 970                                           MLB
# 971                                   Scotty Sire
# 972                       Eurovision Song Contest
# 973                               Cartoon Network
# 974                       Eurovision Song Contest
# 975  DaniRep | +6 Vídeos Diarios De GTA 5 Online!
# 976                                  Melvin Gregg
# 977                       Eurovision Song Contest
# 978                             Think Music India
# 979                       Eurovision Song Contest
# 980                       Eurovision Song Contest
# 981                       Eurovision Song Contest
# 982                                  Men's Health
# 983                                   David Lopez
# 984                                       TipHero
# 985                                     Tastemade
# 986                       Eurovision Song Contest
# 987                       Eurovision Song Contest
# 988                                   Scotty Sire
# 989                       Eurovision Song Contest
# 990                       Eurovision Song Contest
# 991                       Eurovision Song Contest
# 992                       Eurovision Song Contest
# 993                       Eurovision Song Contest
# 994                       Eurovision Song Contest
# 995                       Eurovision Song Contest
# 996                       Eurovision Song Contest
# 997                       Eurovision Song Contest
# 998                       Eurovision Song Contest
# 999                                      NBC News
#
#                          Final_Neighbor_2  \
# 0                        OneDirectionVEVO
# 1                          Baby Big Mouth
# 2                            PrankvsPrank
# 3                              Toy Freaks
# 4                       Zee Music Company
# 5                       Mother Goose Club
# 6                            OHA diyorum!
# 7                      Masha and The Bear
# 8                     SuperHeroes ForReal
# 9                         LittleBabyBum ®
# 10                          DisneyCarToys
# 11                      Jimmy Kimmel Live
# 12                        Rihanna - Topic
# 13                         stampylonghead
# 14                        SelenaGomezVEVO
# 15   DuckDuckKidsTV [ Duck Duck Kids TV ]
# 16                      ChuChuTV Surprise
# 17                              LMFAOVEVO
# 18                 Капуки Дети и Родители
# 19                        Ryan ToysReview
# 20                           BuzzFeedBlue
# 21                 Canciones De La Granja
# 22                          jacksepticeye
# 23                           TV3 Official
# 24                                SSundee
# 25                     SR Toys Collection
# 26                           ABS-CBN News
# 27                           BuzzFeedBlue
# 28                       SevenAwesomeKids
# 29                                 fixiki
# ..                                    ...
# 970                 Golden State Warriors
# 971                          Amanda Cerny
# 972                         Joey Graceffa
# 973                  Fresh Movie Trailers
# 974                         Joey Graceffa
# 975                              Doc Tops
# 976                  TheOfficialLoganPaul
# 977                         Joey Graceffa
# 978                              CNNMoney
# 979                         Joey Graceffa
# 980                         Joey Graceffa
# 981                         Joey Graceffa
# 982                    The Times of India
# 983                  TheOfficialLoganPaul
# 984                                  avex
# 985                      Mightyduck World
# 986                         Joey Graceffa
# 987                         Joey Graceffa
# 988                       Manual do Mundo
# 989                         Joey Graceffa
# 990                         Joey Graceffa
# 991                         Joey Graceffa
# 992                         Joey Graceffa
# 993                         Joey Graceffa
# 994                         Joey Graceffa
# 995                         Joey Graceffa
# 996                         Joey Graceffa
# 997                         Joey Graceffa
# 998                         Joey Graceffa
# 999                              Sky News
#
#                           Final_Neighbor_3  \
# 0                              RihannaVEVO
# 1                         FunToyzCollector
# 2                     JoBlo Movie Trailers
# 3            Surprise Collector & Sunshine
# 4                       SonyMusicIndiaVEVO
# 5                           Baby Big Mouth
# 6                                   YAPYAP
# 7                 ChuChu TV Nursery Rhymes
# 8                   Superheroes Life S. L.
# 9                           Baby Big Mouth
# 10                        FunToyzCollector
# 11                               Team Coco
# 12                              Young Thug
# 13                           jacksepticeye
# 14                         TaylorSwiftVEVO
# 15                         Ryan ToysReview
# 16                           CVS 3D Rhymes
# 17                        Atlantic Records
# 18                       ✿ Kids Diana Show
# 19   Blu Toys Surprise Brinquedos & Juegos
# 20                          BuzzFeedViolet
# 21                 LittleBabyBum ® Español
# 22                                   Jelly
# 23                   RsiamMusic : อาร์สยาม
# 24    LittleLizardGaming - Minecraft Mods!
# 25                         Family Fun Pack
# 26                         News5Everywhere
# 27             Fine Brothers Entertainment
# 28                            CookieSwirlC
# 29                              Барбоскины
# ..                                     ...
# 970                      Theme Park Review
# 971                            JAY VERSACE
# 972                       baby's adventure
# 973                                  Tasty
# 974                       baby's adventure
# 975                           Robin Schulz
# 976                            Scotty Sire
# 977                       baby's adventure
# 978                            Star Sports
# 979                       baby's adventure
# 980                       baby's adventure
# 981                       baby's adventure
# 982                          GMM25Thailand
# 983                                Show TV
# 984                              Tastemade
# 985                               GameSpot
# 986                       baby's adventure
# 987                       baby's adventure
# 988                            itsLance210
# 989                       baby's adventure
# 990                       baby's adventure
# 991                       baby's adventure
# 992                       baby's adventure
# 993                       baby's adventure
# 994                       baby's adventure
# 995                       baby's adventure
# 996                       baby's adventure
# 997                       baby's adventure
# 998                       baby's adventure
# 999                               CBC News
#
#                                       Final_Neighbor_6  \
# 0                                      SelenaGomezVEVO
# 1                Blu Toys Surprise Brinquedos & Juegos
# 2                                         CollegeHumor
# 3                                          Toy Monster
# 4                                            SET India
# 5                                        CVS 3D Rhymes
# 6                                            Scorp App
# 7                                      Маша та Ведмідь
# 8                               SuperHero VS SuperHero
# 9                                    Mother Goose Club
# 10                                         Toy Monster
# 11                                        CaseyNeistat
# 12                                        kevingatesTV
# 13                                             SSundee
# 14                                    ArianaGrandeVevo
# 15                                   Mother Goose Club
# 16   Videogyan 3D Rhymes - Nursery Rhymes & Childre...
# 17                                  michaeljacksonVEVO
# 18                                              fixiki
# 19                   Toys and Funny Kids Surprise Eggs
# 20                                        BuzzFeedFood
# 21                                      DisneyJuniorLA
# 22                         Fine Brothers Entertainment
# 23                            GMM GRAMMY GOLD OFFICIAL
# 24                              Little Kelly Minecraft
# 25                                         Toy Monster
# 26                                             Howcast
# 27                                         Screen Rant
# 28                                 Wassabi Productions
# 29                                     Супер Развитойз
# ..                                                 ...
# 970                                         Movieclips
# 971                                       Funny Or Die
# 972                                           Капуки4+
# 973                                         FutureVEVO
# 974                                           Капуки4+
# 975                                        Trap Nation
# 976                                     BachelorsPadTv
# 977                                           Капуки4+
# 978                                                CNN
# 979                                           Капуки4+
# 980                                           Капуки4+
# 981                                           Капуки4+
# 982                                         KjraGaming
# 983                                       Amanda Cerny
# 984                                   jypentertainment
# 985                                     Thomas Sanders
# 986                                           Капуки4+
# 987                                           Капуки4+
# 988                                         Liza Koshy
# 989                                           Капуки4+
# 990                                           Капуки4+
# 991                                           Капуки4+
# 992                                           Капуки4+
# 993                                           Капуки4+
# 994                                           Капуки4+
# 995                                           Капуки4+
# 996                                           Капуки4+
# 997                                           Капуки4+
# 998                                           Капуки4+
# 999                                    LastWeekTonight
#
#                                       Final_Neighbor_8
# 0                                             emimusic
# 1                                          Hulyan Maya
# 2                                 SuperHero Reality TV
# 3                                                Vat19
# 4                                              Rajshri
# 5                              LittleBabyBum ® Español
# 6                                                  atv
# 7                                           Teremok TV
# 8                                            Acunn.com
# 9                                           Teremok TV
# 10                Parque dos Brinquedos Disneybabytoys
# 11                                   BlastphamousHD TV
# 12                                         Yippee Toys
# 13                                            Slogoman
# 14                                    NickiMinajAtVEVO
# 15   Awesome Toys Collectors (Giant Egg Surprise, T...
# 16                                         Ultra Hindi
# 17                                Warner Bros. Records
# 18                                          SlivkiShow
# 19                Parque dos Brinquedos Disneybabytoys
# 20                                         TomoNews US
# 21                                           enchufetv
# 22                                         elrubiusOMG
# 23                                           rsfriends
# 24                                         rezendeevil
# 25                                           Heopop 허팝
# 26                                      Анатолий Шарий
# 27                                          netd müzik
# 28                                     alqudsnewspaper
# 29                                          SlivkiShow
# ..                                                 ...
# 970                                            NowThis
# 971                                       CurtisLepore
# 972                                      GOOD Magazine
# 973                                   SevenAwesomeKids
# 974                                        Filmi Gaane
# 975                                               Yuya
# 976                                    Brittany Furlan
# 977                                   NickiMinajAtVEVO
# 978                                 Superhero Fun Life
# 979                                         TheRichest
# 980                               SuperHero Reality TV
# 981                                          Bizim Yol
# 982                                            NowThis
# 983                                        Scotty Sire
# 984                              Good Mythical Morning
# 985                                   Business Insider
# 986                                       TheEllenShow
# 987                               CalibreCincuentaVEVO
# 988                                          Bizim Yol
# 989                                   Fun Super Heroes
# 990                                        Beto Sierra
# 991                               SuperHero Reality TV
# 992                                     Channel 4 News
# 993                                        Coke Studio
# 994                                     Inside Edition
# 995                                   DokuzSekiz Müzik
# 996                                          enchufetv
# 997                                   DokuzSekiz Müzik
# 998                                         TheRichest
# 999                                          Acunn.com
#
# [1000 rows x 6 columns]

# %%
## ADD FINAL NEIGHBORS IDS:
nn1_list_id = list()
nn2_list_id = list()
nn3_list_id = list()
for i in range(1,10):
    nn1_list_id.append('model1_NN_'+str(i)+'_id')
    nn2_list_id.append('model2_NN_'+str(i)+'_id')
    nn3_list_id.append('model3_NN_'+str(i)+'_id')
print(nn1_list_id)

data_channels = add_final(data_channels, nn1_list_id, 6, nn2_list_id, 2, nn3_list_id, 2, 'Final_Neighbor_', '_ID')
# Out:
# ['model1_NN_1_id', 'model1_NN_2_id', 'model1_NN_3_id', 'model1_NN_4_id', 'model1_NN_5_id', 'model1_NN_6_id', 'model1_NN_7_id', 'model1_NN_8_id', 'model1_NN_9_id']

# %%
data_channels[[ 'YT_Title','Final_Neighbor_1', 'Final_Neighbor_1_ID', 'Final_Neighbor_8', 'Final_Neighbor_8_ID']]
# Out:
#                                     YT_Title  \
# 0                           JustinBieberVEVO
# 1                            Ryan ToysReview
# 2                                        WWE
# 3                            Family Fun Pack
# 4                                   T-Series
# 5                            LittleBabyBum ®
# 6                                 netd müzik
# 7                             Маша и Медведь
# 8                                Toy Monster
# 9                                 Get Movies
# 10                 Disney Cars Toy Club DCTC
# 11                              TheEllenShow
# 12                             Drake - Topic
# 13              TheDiamondMinecart // DanTDM
# 14                               RihannaVEVO
# 15                            Baby Big Mouth
# 16                  ChuChu TV Nursery Rhymes
# 17                                  emimusic
# 18                                 Miss Katy
# 19                          FunToyzCollector
# 20                             BuzzFeedVideo
# 21                         El Reino Infantil
# 22                                 PewDiePie
# 23                       GMM GRAMMY OFFICIAL
# 24                               PopularMMOs
# 25                                ToyMonster
# 26                     ABS-CBN Entertainment
# 27                             WatchMojo.com
# 28                           SevenSuperGirls
# 29                                Mister Max
# ..                                       ...
# 970                                 slamball
# 971                          Brittany Furlan
# 972                                 Upworthy
# 973                       The Wall of Comedy
# 974                                Jaan Arya
# 975                           Chef Kiwilimón
# 976                             CurtisLepore
# 977                               Lil Crazed
# 978                      Sky Sports Football
# 979                                Bizim Yol
# 980                                  NowThis
# 981                              MONTREALITY
# 982                                 Facebook
# 983                             Rudy Mancuso
# 984                             Food Network
# 985                         Spoon University
# 986                                     HGTV
# 987                        PZS ENTERTAINMENT
# 988                              HipHopVines
# 989                       Japonês da Federal
# 990                              bandeandofm
# 991                                      Mic
# 992                                   helloU
# 993                                    3ga2b
# 994  The Black Jaguar White Tiger Foundation
# 995                         PlayGround Video
# 996                       شبكة قدس الاخبارية
# 997                              Milly Wessy
# 998                     Collective Evolution
# 999                                Global TV
#
#                                  Final_Neighbor_1     Final_Neighbor_1_ID  \
# 0                                 TaylorSwiftVEVO  ANLZYMidaCbLQFWXBC95Jg
# 1                                 Family Fun Pack  vthuVsurPaVz2a7_4LepGg
# 2                             Movieclips Trailers  i8e0iOVk1fEOogdfu4YgfA
# 3                                 Ryan ToysReview  hGJGhZ9SOOHvBB0Y4DOO_w
# 4                                        Eros Now  X52tYZiEh_mHoFja3Veciw
# 5                        ChuChu TV Nursery Rhymes  BnZ16ahKA2DZ_T5W0FPUXg
# 6                                DokuzSekiz Müzik  bCFxJq-fCwiEo9CgowI7CQ
# 7                                      Get Movies  lZkHt2kNIgyrTTPnSQV3SA
# 8                                       HeroesIRL  k_GTlc9ARh6MuU61DUemnQ
# 9                                  Маша и Медведь  Rv76wLBC73jiP7LX4C3l8Q
# 10                                   CookieSwirlC  elMeixAOTs2OQAAi9wU8-g
# 11         The Tonight Show Starring Jimmy Fallon  8-Th83bH_thdKZDJCrn88g
# 12                                 Future - Topic  1_liDR4fRFJgH4HoJeV8cw
# 13                                    PopularMMOs  pGdL9Sn3Q5YWUH2DVUW1Ug
# 14                               JustinBieberVEVO  Hkj014U2CQ2Nv0UZeYpE_A
# 15                                LittleBabyBum ®  KAqou7V9FAWXpZd9xtOg3Q
# 16                                LittleBabyBum ®  KAqou7V9FAWXpZd9xtOg3Q
# 17                              BritneySpearsVEVO  ZijND2e2tPp2AQL8Go2YSg
# 18                                     Mister Max  _8PAD0Qmi6_gpe77S1Atgg
# 19                                 Baby Big Mouth  Wr4vlkj5xXQ4bSXNeTT2AA
# 20                                 BuzzFeedYellow  ay_OLhWtf9iklq8zg_or0g
# 21                               GallinaPintadita  KdEsgHiM0SulsFXm7QMJAg
# 22                                     Markiplier  7_YxT-KID8kRbqZo7MyscQ
# 23                                       ช่อง one  8f7MkX4MFOOJ2SerXLInCA
# 24                   TheDiamondMinecart // DanTDM  S5Oz6CHmeoF7vSad0qqXfw
# 25              Toys and Funny Kids Surprise Eggs  wjoPtSoNLAoX2sLBaKLYng
# 26                    GMA News and Public Affairs  qYw-CTd1dU2yGI71sEyqNw
# 27                                     TheRichest  dxi8d8qRsRyUi2ERYjYb-w
# 28                             SevenPerfectAngels  mAhUhCZbPq8RTt9dT9RE2w
# 29                                      Miss Katy  cartHVtvAUzfajflyeT_Gg
# ..                                            ...                     ...
# 970                                           MLB  oLrcjPV5PbUrUyXq5mjc_A
# 971                                   Scotty Sire  ptRmkkO5t2wGbF2qyjaMCA
# 972                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 973                               Cartoon Network  MsgXPD3wzzt8RxHJmXH7hQ
# 974                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 975  DaniRep | +6 Vídeos Diarios De GTA 5 Online!  HIwQiZhIn6fm5b_IilqBbQ
# 976                                  Melvin Gregg  -5PffJnOZrSLgV6Ur2UUfw
# 977                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 978                             Think Music India  LbdVvreihwZRL6kwuEUYsA
# 979                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 980                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 981                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 982                                  Men's Health  wJfDTNqtM5n-dQBfuuHzYw
# 983                                   David Lopez  uanFncsQWzKrmyxB5CXs5A
# 984                                       TipHero  HaumraHW4B2xJdhVuWSK7w
# 985                                     Tastemade  qf_rFCGLODeUcw3p_Abr-A
# 986                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 987                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 988                                   Scotty Sire  ptRmkkO5t2wGbF2qyjaMCA
# 989                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 990                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 991                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 992                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 993                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 994                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 995                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 996                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 997                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 998                       Eurovision Song Contest  RpjHHu8ivVWs73uxHlWwFA
# 999                                      NBC News  eY0bbntWzzVIaj2z3QigXg
#
#                                       Final_Neighbor_8     Final_Neighbor_8_ID
# 0                                             emimusic  2kTZB_yeYgdAg4wP2tEryA
# 1                                          Hulyan Maya  3AgxXIspxGB8Mb-6bO9YlA
# 2                                 SuperHero Reality TV  hikza6yUVgrs7L879pzZyw
# 3                                                Vat19  DRbNGFusqlXX4a5vwi9ouQ
# 4                                              Rajshri  EKWXRsfUHkan-D_ljU8Asw
# 5                              LittleBabyBum ® Español  HicabXz9rUMWLcdMqBtbxQ
# 6                                                  atv  UVZ7T_kwkxDOGFcDlFI-hg
# 7                                           Teremok TV  xWkNmkeAL52VTJyBlIJRXw
# 8                                            Acunn.com  LBwKhRQL0ORY3GB8c2l5cg
# 9                                           Teremok TV  xWkNmkeAL52VTJyBlIJRXw
# 10                Parque dos Brinquedos Disneybabytoys  qK5vXeApwrOm5S6QrlrK-w
# 11                                   BlastphamousHD TV  trIvE-HULm9jbgzN26AG-Q
# 12                                         Yippee Toys  iw97Iyd9CbAyr00D94v3tg
# 13                                            Slogoman  HdMK5Ef2El8KbD3L_WgANg
# 14                                    NickiMinajAtVEVO  aum3Yzdl3TbBt8YUeUGZLQ
# 15   Awesome Toys Collectors (Giant Egg Surprise, T...  jZQZLWjDvGDeA4i9VgkgPQ
# 16                                         Ultra Hindi  mL1WlDI8UkXDXCXcBQN9CA
# 17                                Warner Bros. Records  Dj64sior23IP_7xLe8R7sg
# 18                                          SlivkiShow  U_yU4xGT9hrVFo6euH8LLw
# 19                Parque dos Brinquedos Disneybabytoys  qK5vXeApwrOm5S6QrlrK-w
# 20                                         TomoNews US  t-WqkTyKK1_70U4bb4k4lQ
# 21                                           enchufetv  oGDh1Xa3kUCpok24JN5DKA
# 22                                         elrubiusOMG  XazgXDIYyWH-yXLAkcrFxw
# 23                                           rsfriends  8GkZ5dlOrw-yN_nkOAIzPA
# 24                                         rezendeevil  bTVTephX30ZhQF5zwFppBg
# 25                                           Heopop 허팝  k6bX-MZXdte_7kG8TbMkqg
# 26                                      Анатолий Шарий  VPYbobPRzz0SjinWekjUBw
# 27                                          netd müzik  R5wZcXtOUka8jTA57flzMg
# 28                                     alqudsnewspaper  yO6eecfVeb369vgRiQFUew
# 29                                          SlivkiShow  U_yU4xGT9hrVFo6euH8LLw
# ..                                                 ...                     ...
# 970                                            NowThis  n4sPeUomNGIr26bElVdDYg
# 971                                       CurtisLepore  sgMB2AZAPurPKT9HdoQmiA
# 972                                      GOOD Magazine  eHHAF22PljrnnjskZeljmg
# 973                                   SevenAwesomeKids  7LoPchI2eDpoEanAff27pw
# 974                                        Filmi Gaane  P6uH_XlsxrXwZQ4DlqbqPg
# 975                                               Yuya  BNs31xysxpAGMheg8OrngA
# 976                                    Brittany Furlan  sxN0GZ8MHeVbMkXlhrbXGw
# 977                                   NickiMinajAtVEVO  aum3Yzdl3TbBt8YUeUGZLQ
# 978                                 Superhero Fun Life  EOb5CMH08BQfoj0O0yj6eQ
# 979                                         TheRichest  dxi8d8qRsRyUi2ERYjYb-w
# 980                               SuperHero Reality TV  hikza6yUVgrs7L879pzZyw
# 981                                          Bizim Yol  9UdM5xkaYRgO3ItqUrjyrA
# 982                                            NowThis  n4sPeUomNGIr26bElVdDYg
# 983                                        Scotty Sire  ptRmkkO5t2wGbF2qyjaMCA
# 984                              Good Mythical Morning  4PooiX37Pld1T8J5SYT-SQ
# 985                                   Business Insider  cyq283he07B7_KUX07mmtA
# 986                                       TheEllenShow  p0hYYBW6IMayGgR-WeoCvQ
# 987                               CalibreCincuentaVEVO  oAXIMqrhLmnGTkdsrna3cw
# 988                                          Bizim Yol  9UdM5xkaYRgO3ItqUrjyrA
# 989                                   Fun Super Heroes  Mf0z8xGZI3NALP0QJRS2tg
# 990                                        Beto Sierra  cLacBOybtmDLn3uAFemW_A
# 991                               SuperHero Reality TV  hikza6yUVgrs7L879pzZyw
# 992                                     Channel 4 News  TrQ7HXWRRxr7OsOtodr2_w
# 993                                        Coke Studio  AmuBPgmOEeQ2B9MEW5k92w
# 994                                     Inside Edition  9k-yiEpRHMNVOnOi_aQK8w
# 995                                   DokuzSekiz Müzik  bCFxJq-fCwiEo9CgowI7CQ
# 996                                          enchufetv  oGDh1Xa3kUCpok24JN5DKA
# 997                                   DokuzSekiz Müzik  bCFxJq-fCwiEo9CgowI7CQ
# 998                                         TheRichest  dxi8d8qRsRyUi2ERYjYb-w
# 999                                          Acunn.com  LBwKhRQL0ORY3GB8c2l5cg
#
# [1000 rows x 5 columns]

# %%
# save results of the 1st AND 2nd AND 3d models:
import csv
data_channels.to_csv('A:\PROGRAMMING\Final_results.csv', 
                                             sep = ',' ,index= False,encoding = 'utf-8')
